# %%
out = [(x, y, z) for x in (1,0) for y in (1,0) for z in (1,0)]

# %%
xvalues = [1,1,1,1,0,0,0,0]
yvalues = [1,1,0,0,1,1,0,0]
zvalues = [1,0,1,0,1,0,1,0]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 


fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot (rout, rout, 'ro')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-736729471545> in <module>()
#       6 ax = fig.gca(projection='3d')
#       7
# ----> 8 plt.plot (rout, rout, 'ro')
#
# NameError: name 'rout' is not defined

# %%
import numpy as np
np.asarray(xvalues)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 

x = xvalues
y = yvalues
z = zvalues

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(x, y, z, 'bo')

plt.show()

# %%
xvalues = [1,1,1,1,0,0,0,0]
yvalues = [1,1,0,0,1,1,0,0]
zvalues = [1,0,1,0,1,0,1,0]
xvaluesin = [1,.5,.5,0,.5,.5]
yvaluesin = [.5,.5,1,.5,.5,0]
zvaluesin = [.5,1,.5,.5,0,.5]
xweird = [.25, .75, .25, .75]
yweird = [.75, .75, .25, .25]
zweird = [.75, .25, .25, .75]

# %%
fbox = np.zeros((18,3))
fbox[:,0] = xvalues + xvaluesin + xweird
fbox[:,1] = yvalues + yvaluesin + yweird
fbox[:,2] = zvalues + zvaluesin + zweird
print(fbox)

# %%
hbox = fbox[4:18]
hbox.remove(hbox[9])
print(hbox)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = xvalues
y = yvalues
z = zvalues
xin = xvaluesin
yin = yvaluesin
zin = zvaluesin
xw = xweird
yw = yweird
zw = zweird

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(xin, yin, zin,'o')
plt.plot(x, y, z, 'o')
#plt.plot(xw, yw, zw, 'ro')

plt.show()

# %%
xtotal=[0, .25, .5, .75, 1, .75, .5, .75, 1, .75, 1, .75, .5, .25, .5, .75, .5, .25, 0, .25, .5, .25, 0, .25]
ytotal=[0, .25, .5, .75, 1, .75, 1, .75, .5, .25, 0, .25, 0, .25, 0, .25, .5, .75, 1, .75, 1, .75, .5, .25]
ztotal=[0, .25, 0, .25, 0, .25, .5, .25, .5, .75, 1, .75, .5, .25, .5, .75, 1, .75, 1, .75, .5, .75, .5, .25]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = xvalues
y = yvalues
z = zvalues
xin = xvaluesin
yin = yvaluesin
zin = zvaluesin
xw = xweird
yw = yweird
zw = zweird
xt=xtotal
yt=ytotal
zt=ztotal

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(xin, yin, zin,'o')
plt.plot(x, y, z, 'bo-')
plt.plot(xw, yw, zw, 'ro')
#plt.plot(xt, yt, zt, '-')

plt.show()

# %%
import numpy as np
L = 1

data = np.zeros((18,3))
xbox = data[:,0]
ybox = data[:,1]
zbox = data[:,2]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 
fig = plt.figure()

fig = plt.figure()
ax = fig.gca(projection='3d')


for i in range(0,8):
    xvalues = [i,i,(i+1),(i+1),i,i,i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i]
    yvalues = [i,(i+1),(i+1),i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i,i,i,i]
    zvalues = [i,i,i,i,i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1)]
    plt.plot(xvalues, yvalues, zvalues, 'bo-')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 
fig = plt.figure()

fig = plt.figure()
ax = fig.gca(projection='3d')


for i in range(0,2):
    xtotal=[(i), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+.5), (i+.25), i, (i+.25), (i+.5), (i+.25), i, (i+.25)]
    for i in range(0,2):
        ytotal=[i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25)]
        for i in range(0,2):
            ztotal=[0, .25, 0, .25, 0, .25, .5, .25, .5, .75, 1, .75, .5, .25, .5, .75, 1, .75, 1, .75, .5, .75, .5, .25]
    #xvalues = [i,i,(i+1),(i+1),i,i,i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i]
    #yvalues = [i,(i+1),(i+1),i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i,i,i,i]
    #zvalues = [i,i,i,i,i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1)]
            plt.plot(xtotal, ytotal, ztotal, 'bo-')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 
fig = plt.figure()

fig = plt.figure()
ax = fig.gca(projection='3d')

for i in range(0,2):
    xvalues = [i,i,(i+1),(i+1),i,i,i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i]
    xtotal=[(i), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+.5), (i+.25), i, (i+.25), (i+.5), (i+.25), i, (i+.25)]
    for i in range(0,2):
        yvalues = [i,(i+1),(i+1),i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i,i,i,i]
        ytotal=[i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25)]
        for i in range(0,2):   
            zvalues = [i,i,i,i,i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1)]
            ztotal=[i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+.5), (i+.25)]
            plt.plot(xvalues, yvalues, zvalues, 'b-')
            plt.plot(xtotal, ytotal, ztotal, 'o-')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 
fig = plt.figure()

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(0, 10)
ax.set_ylim3d(0,10)
ax.set_zlim3d(-10,10)
di = 0

for i in range(0,11):
    for i in range(0,11):
        xvalues = [i,i,(i+1),(i+1),i,i,i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i]
        xtotal=[(i), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+.5), (i+.25), i, (i+.25), (i+.5), (i+.25), i, (i+.25)]
        for i in range(0,8):
            yvalues = [i,(i+1),(i+1),i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i,i,i,i]
            ytotal=[i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25)]
            for i in range(0,5):   
                zvalues = [i,i,i,i,i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1)]
                ztotal=[i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+.5), (i+.25)]
                plt.plot(xvalues, yvalues, zvalues, 'b-')
                plt.plot(xtotal, ytotal, ztotal, 'o-')
            di = di
plt.show()
for angle in range(0,360):
    ax.view_init(90,angle)
    plt.draw()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 
fig = plt.figure()

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlim3d(0, 10)
ax.set_ylim3d(0,10)
ax.set_zlim3d(-10,10)
di = 0

for i in range(0,5):
    di = di - 1
    for i in range(0,11+di):
        xvalues = [i,i,(i+1),(i+1),i,i,i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i]
        xtotal=[(i), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+.5), (i+.25), i, (i+.25), (i+.5), (i+.25), i, (i+.25)]
        for i in range(0,8):
            yvalues = [i,(i+1),(i+1),i,i,i,(i+1),(i+1),(i+1),(i+1),(i+1),(i+1),i,i,i,i]
            ytotal=[i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.25)]
            for i in range(0,5):   
                zvalues = [i,i,i,i,i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1),i,(i+1),(i+1)]
                ztotal=[i, (i+.25), i, (i+.25), i, (i+.25), (i+.5), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+.5), (i+.25), (i+.5), (i+.75), (i+1), (i+.75), (i+1), (i+.75), (i+.5), (i+.75), (i+.5), (i+.25)]
                plt.plot(xvalues, yvalues, zvalues, 'b-')
                plt.plot(xtotal, ytotal, ztotal, 'o-') 
plt.show()

# %%
di = 0 
for i in range(0,5):
    di = di -1
    print(di)
# Out:
# -1
# -2
# -3
# -4
# -5
