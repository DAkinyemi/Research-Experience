# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 

xvalues = (1,1,1,1,1,0,0,0,0)
yvalues = (1,1,0,0,.5,1,1,0,0)
zvalues = (1,0,1,0,.5,1,0,1,0)
xplane = (.5,.5,0,.5,.5)
yplane = (.5,1,.5,.5,0)
zplane = (1,.5,.5,0,.5)
xin = (.25, .75, .25, .75)
yin = (.75, .75, .25, .25)
zin = (.75, .25, .25, .75)

# %%
#Creates full box
fbox = np.zeros((18,3))
fbox[:,0] = xvalues + xplane +xin
fbox[:,1] = yvalues + yplane +yin
fbox[:,2] = zvalues + zplane +zin
#print(fbox)

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(fbox[:,0],fbox[:,1],fbox[:,2], 'o')

# %%
#Removed the left wall

jxvalues = (1,1,1,1,1)
jyvalues = (1,1,0,0,.5)
jzvalues = (1,0,1,0,.5)
jxplane = (.5,.5,.5,.5)
jyplane = (.5,1,.5,0)
jzplane = (1,.5,0,.5)
jxin = (.25, .75, .25, .75)
jyin = (.75, .75, .25, .25)
jzin = (.75, .25, .25, .75)

hlbox = np.zeros((13,3))
hlbox[:,0] = jxvalues + jxplane + jxin
hlbox[:,1] = jyvalues + jyplane + jyin
hlbox[:,2] = jzvalues + jzplane + jzin


#print(hlbox)

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(hlbox[:,0],hlbox[:,1],hlbox[:,2], 'o')

# %%
#Removed the bottom wall
qxvalues = (1,1,1,0,0)
qyvalues = (1,0,.5,1,0)
qzvalues = (1,1,.5,1,1)
qxplane = (.5,.5,0,.5)
qyplane = (.5,1,.5,0)
qzplane = (1,.5,.5,.5)
qxin = (.25, .75, .25, .75)
qyin = (.75, .75, .25, .25)
qzin = (.75, .25, .25, .75)

ybbox = np.zeros((13,3))
ybbox[:,0] = qxvalues + qxplane + qxin
ybbox[:,1] = qyvalues + qyplane + qyin
ybbox[:,2] = qzvalues + qzplane + qzin


#print(ybbox)

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(ybbox[:,0],ybbox[:,1],ybbox[:,2], 'o')

# %%
#Removed the back wall
zbxvalues = (1,1,1,0,0)
zbyvalues = (0,0,.5,0,0)
zbzvalues = (1,0,.5,1,0)
zbxplane = (.5,0,.5,.5)
zbyplane = (.5,.5,.5,0)
zbzplane = (1,.5,0,.5)
zbxin = (.25, .75, .25, .75)
zbyin = (.75, .75, .25, .25)
zbzin = (.75, .25, .25, .75)

zbbox = np.zeros((13,3))
zbbox[:,0] = zbxvalues + zbxplane + zbxin
zbbox[:,1] = zbyvalues + zbyplane + zbyin
zbbox[:,2] = zbzvalues + zbzplane + zbzin


#print(ybbox)
fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(zbbox[:,0],zbbox[:,1],zbbox[:,2], 'o')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
plt.plot(zbbox[:,0],zbbox[:,1],zbbox[:,2], 'o')
plt.plot(zbbox[:,0]+1,zbbox[:,1],zbbox[:,2], 'o')

# %%
#Creates full box
fbox = np.zeros((18,3))
fbox[:,0] = xvalues + xplane +xin
fbox[:,1] = yvalues + yplane +yin
fbox[:,2] = zvalues + zplane +zin

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(fbox[:,0],fbox[:,1],fbox[:,2], 'o')

# %%
#Create full box
fbox = np.zeros((18,3))
fbox[:,0] = xvalues + xplane +xin
fbox[:,1] = yvalues + yplane +yin
fbox[:,2] = zvalues + zplane +zin

#Box with left wall removed coordintates 
jxvalues = (1,1,1,1,1)
jyvalues = (1,1,0,0,.5)
jzvalues = (1,0,1,0,.5)
jxplane = (.5,.5,.5,.5)
jyplane = (.5,1,.5,0)
jzplane = (1,.5,0,.5)
jxin = (.25, .75, .25, .75)
jyin = (.75, .75, .25, .25)
jzin = (.75, .25, .25, .75)
#Box with right wall removed coordintates 
xvaluesr = (0,0,0,0)
yvaluesr = (1,1,0,0)
zvaluesr = (1,0,1,0)
xpr = (.5,.5,0,.5,.5)
ypr = (.5,1,.5,.5,0)
zpr = (1,.5,.5,0,.5)
#Box with bottom wall removed coordintates 
qxvalues = (1,1,1,0,0)
qyvalues = (1,0,.5,1,0)
qzvalues = (1,1,.5,1,1)
qxplane = (.5,.5,0,.5)
qyplane = (.5,1,.5,0)
qzplane = (1,.5,.5,.5)
qxin = (.25, .75, .25, .75)
qyin = (.75, .75, .25, .25)
qzin = (.75, .25, .25, .75)
#Box with top wall removed coordintates 
xvaluest = (1,1,0,0)
yvaluest = (0,0,0,0)
zvaluest = (1,0,0,1)
xpt = (.5,0,.5,.5,1)
ypt = (1,.5,.5,0,.5)
zpt = (.5,.5,0,.5,.5)
#Box with back wall removed coordintates 
zbxvalues = (1,1,1,0,0)
zbyvalues = (0,0,.5,0,0)
zbzvalues = (1,0,.5,1,0)
zbxplane = (.5,0,.5,.5)
zbyplane = (.5,.5,.5,0)
zbzplane = (1,.5,0,.5)
zbxin = (.25, .75, .25, .75)
zbyin = (.75, .75, .25, .25)
zbzin = (.75, .25, .25, .75)
#Box with front wall removed coordintates 
xvaluesf = (1,1,0,0)
yvaluesf = (1,0,1,0)
zvaluesf = (0,0,0,0)
xpf = (.5,0,.5,.5,1)
ypf = (1,.5,.5,0,.5)
zpf = (.5,.5,0,.5,.5)

#Assigning specific coordinates to certain variables 
hlbox = np.zeros((13,3))
hlbox[:,0] = jxvalues + jxplane + jxin
hlbox[:,1] = jyvalues + jyplane + jyin
hlbox[:,2] = jzvalues + jzplane + jzin
hrbox = np.zeros ((13,3))
hrbox[:,0] = xvaluesr +xpr +xin
hrbox[:,1] = yvaluesr +ypr +yin
hrbox[:,2] = zvaluesr +zpr +zin
ybbox = np.zeros((13,3))
ybbox[:,0] = qxvalues + qxplane + qxin
ybbox[:,1] = qyvalues + qyplane + qyin
ybbox[:,2] = qzvalues + qzplane + qzin
yboxt = np.zeros ((13,3))
yboxt[:,0] = xvaluest +xpt +xin
yboxt[:,1] = yvaluest +ypt +yin
yboxt[:,2] = zvaluest +zpt +zin
zbbox = np.zeros((13,3))
zbbox[:,0] = zbxvalues + zbxplane + zbxin
zbbox[:,1] = zbyvalues + zbyplane + zbyin
zbbox[:,2] = zbzvalues + zbzplane + zbzin
zboxf = np.zeros ((13,3))
zboxf[:,0] = xvaluesf +xpf +xin
zboxf[:,1] = yvaluesf +ypf +yin
zboxf[:,2] = zvaluesf +zpf +zin

#Plotting boxes
fig = plt.figure()
ax = fig.gca(projection='3d')
for i in range (0,10):
    plt.plot(fbox[:,0],fbox[:,1],fbox[:,2], 'o')
    plt.plot(hlbox[:,0] + i,hlbox[:,1] ,hlbox[:,2], 'bo')
    plt.plot(hrbox[:,0] - i,hrbox[:,1] ,hrbox[:,2], 'ro')
    plt.plot(yboxt[:,0],yboxt[:,1],yboxt[:,2] + i, 'yo')
    plt.plot(yboxt[:,0],yboxt[:,1],yboxt[:,2] - i, 'yo')
    plt.plot(zbbox[:,0],zbbox[:,1] + i,zbbox[:,2], 'o')
    plt.plot(zboxf[:,0],zboxf[:,1] - i,zboxf[:,2], 'o')

# %%
#Create full box
fbox = np.zeros((18,3))
fbox[:,0] = xvalues + xplane +xin
fbox[:,1] = yvalues + yplane +yin
fbox[:,2] = zvalues + zplane +zin

#Box with left wall removed coordintates 
jxvalues = (1,1,1,1,1)
jyvalues = (1,1,0,0,.5)
jzvalues = (1,0,1,0,.5)
jxplane = (.5,.5,.5,.5)
jyplane = (.5,1,.5,0)
jzplane = (1,.5,0,.5)
jxin = (.25, .75, .25, .75)
jyin = (.75, .75, .25, .25)
jzin = (.75, .25, .25, .75)
#Box with right wall removed coordintates 
xvaluesr = (0,0,0,0)
yvaluesr = (1,1,0,0)
zvaluesr = (1,0,1,0)
xpr = (.5,.5,0,.5,.5)
ypr = (.5,1,.5,.5,0)
zpr = (1,.5,.5,0,.5)
#Box with bottom wall removed coordintates 
qxvalues = (1,1,1,0,0)
qyvalues = (1,0,.5,1,0)
qzvalues = (1,1,.5,1,1)
qxplane = (.5,.5,0,.5)
qyplane = (.5,1,.5,0)
qzplane = (1,.5,.5,.5)
qxin = (.25, .75, .25, .75)
qyin = (.75, .75, .25, .25)
qzin = (.75, .25, .25, .75)
#Box with top wall removed coordintates 
xvaluest = (1,1,0,0)
yvaluest = (0,0,0,0)
zvaluest = (1,0,0,1)
xpt = (.5,0,.5,.5,1)
ypt = (1,.5,.5,0,.5)
zpt = (.5,.5,0,.5,.5)
#Box with back wall removed coordintates 
zbxvalues = (1,1,1,0,0)
zbyvalues = (0,0,.5,0,0)
zbzvalues = (1,0,.5,1,0)
zbxplane = (.5,0,.5,.5)
zbyplane = (.5,.5,.5,0)
zbzplane = (1,.5,0,.5)
zbxin = (.25, .75, .25, .75)
zbyin = (.75, .75, .25, .25)
zbzin = (.75, .25, .25, .75)
#Box with front wall removed coordintates 
xvaluesf = (1,1,0,0)
yvaluesf = (1,0,1,0)
zvaluesf = (0,0,0,0)
xpf = (.5,0,.5,.5,1)
ypf = (1,.5,.5,0,.5)
zpf = (.5,.5,0,.5,.5)

#Assigning specific coordinates to certain variables 
hlbox = np.zeros((13,3))
hlbox[:,0] = jxvalues + jxplane + jxin
hlbox[:,1] = jyvalues + jyplane + jyin
hlbox[:,2] = jzvalues + jzplane + jzin
hrbox = np.zeros ((13,3))
hrbox[:,0] = xvaluesr +xpr +xin
hrbox[:,1] = yvaluesr +ypr +yin
hrbox[:,2] = zvaluesr +zpr +zin
ybbox = np.zeros((13,3))
ybbox[:,0] = qxvalues + qxplane + qxin
ybbox[:,1] = qyvalues + qyplane + qyin
ybbox[:,2] = qzvalues + qzplane + qzin
yboxt = np.zeros ((13,3))
yboxt[:,0] = xvaluest +xpt +xin
yboxt[:,1] = yvaluest +ypt +yin
yboxt[:,2] = zvaluest +zpt +zin
zbbox = np.zeros((13,3))
zbbox[:,0] = zbxvalues + zbxplane + zbxin
zbbox[:,1] = zbyvalues + zbyplane + zbyin
zbbox[:,2] = zbzvalues + zbzplane + zbzin
zboxf = np.zeros ((13,3))
zboxf[:,0] = xvaluesf +xpf +xin
zboxf[:,1] = yvaluesf +ypf +yin
zboxf[:,2] = zvaluesf +zpf +zin

#Plotting boxes
fig = plt.figure()
ax = fig.gca(projection='3d')
plt.plot(fbox[:,0],fbox[:,1],fbox[:,2], 'o')
for i in range (0,20):
    plt.plot(hlbox[:,0] + i,hlbox[:,1] ,hlbox[:,2], 'bo')
    for i in range(0,20):
        plt.plot(zbbox[:,0] , zbbox[:,1] + i,zbbox[:,2], 'yo')

# %%
#CHANGE ALL XS by adding plus 1, then2, then 3, then 4
#Create full box
fbox = np.zeros((18,3))
fbox[:,0] = xvalues + xplane +xin
fbox[:,1] = yvalues + yplane +yin
fbox[:,2] = zvalues + zplane +zin

#Box with left wall removed coordintates 
jxvalues = (1,1,1,1,1)
jyvalues = (1,1,0,0,.5)
jzvalues = (1,0,1,0,.5)
jxplane = (.5,.5,.5,.5)
jyplane = (.5,1,.5,0)
jzplane = (1,.5,0,.5)
jxin = (.25, .75, .25, .75)
jyin = (.75, .75, .25, .25)
jzin = (.75, .25, .25, .75)
#Box with right wall removed coordintates 
xvaluesr = (0,0,0,0)
yvaluesr = (1,1,0,0)
zvaluesr = (1,0,1,0)
xpr = (.5,.5,0,.5,.5)
ypr = (.5,1,.5,.5,0)
zpr = (1,.5,.5,0,.5)
#Box with bottom wall removed coordintates 
qxvalues = (1,1,1,0,0)
qyvalues = (1,0,.5,1,0)
qzvalues = (1,1,.5,1,1)
qxplane = (.5,.5,0,.5)
qyplane = (.5,1,.5,0)
qzplane = (1,.5,.5,.5)
qxin = (.25, .75, .25, .75)
qyin = (.75, .75, .25, .25)
qzin = (.75, .25, .25, .75)
#Box with top wall removed coordintates 
xvaluest = (1,1,0,0)
yvaluest = (0,0,0,0)
zvaluest = (1,0,0,1)
xpt = (.5,0,.5,.5,1)
ypt = (1,.5,.5,0,.5)
zpt = (.5,.5,0,.5,.5)
#Box with back wall removed coordintates 
zbxvalues = (1,1,1,0,0)
zbyvalues = (0,0,.5,0,0)
zbzvalues = (1,0,.5,1,0)
zbxplane = (.5,0,.5,.5)
zbyplane = (.5,.5,.5,0)
zbzplane = (1,.5,0,.5)
zbxin = (.25, .75, .25, .75)
zbyin = (.75, .75, .25, .25)
zbzin = (.75, .25, .25, .75)
#Box with front wall removed coordintates 
xvaluesf = (1,1,0,0)
yvaluesf = (1,0,1,0)
zvaluesf = (0,0,0,0)
xpf = (.5,0,.5,.5,1)
ypf = (1,.5,.5,0,.5)
zpf = (.5,.5,0,.5,.5)

#Assigning specific coordinates to certain variables 
hlbox = np.zeros((13,3))
hlbox[:,0] = jxvalues + jxplane + jxin
hlbox[:,1] = jyvalues + jyplane + jyin
hlbox[:,2] = jzvalues + jzplane + jzin
hrbox = np.zeros ((13,3))
hrbox[:,0] = xvaluesr +xpr +xin
hrbox[:,1] = yvaluesr +ypr +yin
hrbox[:,2] = zvaluesr +zpr +zin
ybbox = np.zeros((13,3))
ybbox[:,0] = qxvalues + qxplane + qxin
ybbox[:,1] = qyvalues + qyplane + qyin
ybbox[:,2] = qzvalues + qzplane + qzin
yboxt = np.zeros ((13,3))
yboxt[:,0] = xvaluest +xpt +xin
yboxt[:,1] = yvaluest +ypt +yin
yboxt[:,2] = zvaluest +zpt +zin
zbbox = np.zeros((13,3))
zbbox[:,0] = zbxvalues + zbxplane + zbxin
zbbox[:,1] = zbyvalues + zbyplane + zbyin
zbbox[:,2] = zbzvalues + zbzplane + zbzin
zboxf = np.zeros ((13,3))
zboxf[:,0] = xvaluesf +xpf +xin
zboxf[:,1] = yvaluesf +ypf +yin
zboxf[:,2] = zvaluesf +zpf +zin

#Plotting boxes
fig = plt.figure()
ax = fig.gca(projection='3d')
plt.plot(fbox[:,0],fbox[:,1],fbox[:,2], 'o')
for i in range (0,20):
    plt.plot(hlbox[:,0] + i,hlbox[:,1] ,hlbox[:,2], 'bo')
    for i in range(0,20):
        plt.plot(zbbox[:,0] , zbbox[:,1] + i,zbbox[:,2], 'yo')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D #<-- Note the capitalization! 

xvalues = (1,1,1,1,1,0,0,0,0)
yvalues = (1,1,0,0,.5,1,1,0,0)
zvalues = (1,0,1,0,.5,1,0,1,0)
xplane = (.5,.5,0,.5,.5)
yplane = (.5,1,.5,.5,0)
zplane = (1,.5,.5,0,.5)
xin = (.25, .75, .25, .75)
yin = (.75, .75, .25, .25)
zin = (.75, .25, .25, .75)

# %%
#Creates corner box
bbox = np.zeros((18,3))
bbox[:,0] = xvalues + xplane +xin
bbox[:,1] = yvalues + yplane +yin
bbox[:,2] = zvalues + zplane +zin
#print(fbox)

fig = plt.figure()
ax = fig.gca(projection='3d')

plt.plot(bbox[:,0],bbox[:,1],bbox[:,2], 'o')
